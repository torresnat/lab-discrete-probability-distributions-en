# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!
#
# *Notes:*
#
# - Solve the questions with python.
#
# - Round the final answer to three decimal places.

# %%
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## Bernoulli's Distribution
#
# In a basket containing 100 fruits, there are 60 apples and 40 oranges.
#
# A fruit is picked randomly from the basket.
#
# 1. **What is the probability that the fruit is apple?**
# 1. **What is the probability that it is an orange?**

# %%
total_fruits = 100
apples = 60
oranges = 40


p_apple = apples / total_fruits
p_orange = oranges / total_fruits

print(f"Probability of picking an apple: {p_apple:.2f}")
print(f"Probability of picking an orange: {p_orange:.2f}")


x = np.array([0, 1])  # 0 for orange, 1 for apple
bernoulli_probs = stats.bernoulli.pmf(x, p_apple)


plt.bar(x, bernoulli_probs, tick_label=["Orange", "Apple"], color=["orange", "red"])
plt.title("Bernoulli Distribution of Picking a Fruit")
plt.xlabel("Outcome")
plt.ylabel("Probability")
plt.show()
# Out:
# Probability of picking an apple: 0.60
# Probability of picking an orange: 0.40

# %% [markdown]
# Now we take a random sample of 20 fruits from the basket. After each fruit is taken, a new fruit of the same type is replaced in the basket. Therefore, every time we are taking 1 fruit from 100 fruits.
#
# 1. **What is the probability that the first 5 fruits are all apples?**
#
# 1. **What is the probability that the first 5 fruits are all apples and the next 15 fruits are all oranges?**
#
# You can include the `p` and `q` probabilities you previous calculated in your solution.

# %%
total_fruits = 100
apples = 60
oranges = 40


p_apple = apples / total_fruits
p_orange = oranges / total_fruits


p_first_5_apples = p_apple ** 5
print(f"Probability that the first 5 fruits are all apples: {p_first_5_apples:.5f}")


p_first_5_apples_and_next_15_oranges = (p_apple ** 5) * (p_orange ** 15)
print(f"Probability that the first 5 fruits are all apples and the next 15 fruits are all oranges: {p_first_5_apples_and_next_15_oranges:.5f}")
# Out:
# Probability that the first 5 fruits are all apples: 0.07776
# Probability that the first 5 fruits are all apples and the next 15 fruits are all oranges: 0.00000

# %% [markdown]
# ## Binomial Distribution
#
# Similar to the above problem, this time again we randomly sample 20 fruits.
#
# **What is the probability that this time the sample contains 5 apples and 15 oranges?**
#
# Please note that this time the order of the fruits being picked does not matter.

# %%
total_fruits = 100
apples = 60
oranges = 40

# Probabilities
p_apple = apples / total_fruits
p_orange = oranges / total_fruits


n = 20  
k = 5   

binomial_prob = stats.binom.pmf(k, n, p_apple)

print(f"Probability of getting exactly 5 apples and 15 oranges: {binomial_prob:.5f}")
# Out:
# Probability of getting exactly 5 apples and 15 oranges: 0.00129

# %% [markdown]
# In the lesson we also discussed CDF (cumulative distribution function). In the context of the above problem, **what is the probability that less than 5 fruits picked are apples?**
#
# Write the formula and calculate the probability below.

# %%
total_fruits = 100
apples = 60
oranges = 40


p_apple = apples / total_fruits


n = 20  


prob_less_than_5 = stats.binom.cdf(4, n, p_apple)

print(f"Probability that less than 5 fruits picked are apples: {prob_less_than_5:.5f}")
# Out:
# Probability that less than 5 fruits picked are apples: 0.00032

# %% [markdown]
# **Plot the PDF (probability distributiom function) for the above binomial distribution.**
#
# *Hint: The range of x in a binomial distribution is from `0` to `n`.*

# %%
total_fruits = 100
apples = 60
oranges = 40


p_apple = apples / total_fruits


n = 20  


x = np.arange(0, n + 1)


pdf = stats.binom.pmf(x, n, p_apple)


plt.figure(figsize=(10, 6))
plt.bar(x, pdf, color='skyblue', edgecolor='black')
plt.title("Probability Distribution Function of Binomial Distribution", fontsize=14)
plt.xlabel("Number of Apples (x)", fontsize=12)
plt.ylabel("Probability (P(X = x))", fontsize=12)
plt.xticks(x)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ## Poisson Distribution
#
# In this challenge you are required to use the Math library in python to solve the problems.
#
# In the UEFA champions league tournament, the average number of goals scored in a match is 2.3.
#
# **What is the probability that the number of goals scored in a match is 5?**
#
# *Hint: Use the exp() in the math library*
#
# And to calculate the factorial, you can use the following code:
#
# ```python
# import math
# math.factorial(n) # n is the number you want to find the factorial of
# ```

# %%
import math

lambda_ = 2.3  
k = 5          

poisson_prob = (lambda_ ** k * math.exp(-lambda_)) / math.factorial(k)

print(f"Probability of scoring exactly 5 goals in a match: {poisson_prob:.5f}")
# Out:
# Probability of scoring exactly 5 goals in a match: 0.05378

# %% [markdown]
# **Draw a poisson probability distribution plot for the number of goals to be between 0 to 10.**

# %%
# your code here
# Please label the axes and give a title to the plot
